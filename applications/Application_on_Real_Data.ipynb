# %%
import pandas as pd
df = pd.read_excel('mnist.xlsx', index_col=None, header=0)  
df
# Out:
#       sghmc     sgd    sgld     nag
# 0    0.1108  0.1108  0.7490  0.1069
# 1    0.0731  0.0720  0.5869  0.0720
# 2    0.0591  0.0570  0.3652  0.0563
# 3    0.0574  0.0808  0.2600  0.0512
# 4    0.0527  0.1256  0.2079  0.0502
# ..      ...     ...     ...     ...
# 795  0.0162  0.1475  0.0390  0.0168
# 796  0.0162  0.1475  0.0390  0.0168
# 797  0.0162  0.1476  0.0390  0.0169
# 798  0.0162  0.1475  0.0390  0.0169
# 799  0.0162  0.1474  0.0391  0.0169
#
# [800 rows x 4 columns]

# %%
from matplotlib import pyplot as plt
df1 = df[50:][['sghmc', 'sgld','nag']]

# %%
plt.figure(figsize = (12,8))
plt.plot(df1['sghmc'], 'r-.',  label = 'SGHMC')
plt.plot(df1['nag'], 'b--', label = 'SGD with momentum')
plt.plot(df1['sgld'], 'c--', label = 'SGLD')
plt.legend(loc = 1)
plt.ylabel('Test error')
plt.xlabel('Iteration')
plt.savefig("Real_data_1.png")

# %%
plt.figure(figsize = (12,8))
plt.plot(df1['sghmc'], 'r-.',  label = 'SGHMC')
plt.plot(df1['nag'], 'b--', label = 'SGD with momentum')
plt.legend(loc = 1)
plt.ylabel('Test error')
plt.xlabel('Iteration')
plt.savefig("Real_data_2.png")
